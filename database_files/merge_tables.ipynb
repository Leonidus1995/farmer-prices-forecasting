# %%
# loading required packages
import pandas as pd
from sqlalchemy import create_engine

# %%
# creating a connection to the database
engine = create_engine('postgresql+psycopg2://postgres:1995@localhost:5432/faostat_ms_dsci_project')

# list of table names to be read
table_names = [
    'producer_prices', 'production_value', 'production_index', 'crop_production',
    'landuse', 'trade', 'trade_indicators', 'trade_indices', 'economic_indicators', 
    'foreign_investment', 'government_investment', 'credit_to_agri', 'emission_indicators', 
    'employment_indicators', 'annual_population', 'agri_trade_indicators', 
    'nitrogen_fertilizer', 'phosphorus_fertilizer', 'potassium_fertilizer', 
    'cropland_nutrient_balance', 'pesticide', 'pesticide_trade', 'temperature_change'
] 

# dictionary to hold tables
dfs = {name: pd.read_sql_table(name, engine) for name in table_names}

# %%
# this is how we can access individual tables
dfs["trade"].head()
# Out:
#    area_code     area  year_code  year  item_code                     item  \
# 0          1  Armenia       1992  1992         10  Total Merchandise Trade
# 1          1  Armenia       1993  1993         10  Total Merchandise Trade
# 2          1  Armenia       1994  1994         10  Total Merchandise Trade
# 3          1  Armenia       1995  1995         10  Total Merchandise Trade
# 4          1  Armenia       1996  1996         10  Total Merchandise Trade
#
#    export_quantity  export_value  import_quantity  import_value
# 0              NaN       12000.0              NaN      200000.0
# 1              NaN       30000.0              NaN      200000.0
# 2              NaN      232495.0              NaN      393841.0
# 3              NaN      270943.0              NaN      673917.0
# 4              NaN      290314.0              NaN      855801.0

# %%
# set of keys to join the tables on
key_cols_1 = ['area_code', 'area', 'year_code', 'year', 'item_code', 'item']
key_cols_2 = ['area_code', 'area', 'year_code', 'year']

# list of table names (excluding 'producer_prices' and 'crop_production')
table_names = [
    'production_value', 'production_index',
    'landuse', 'trade', 'trade_indicators', 'trade_indices', 'economic_indicators', 
    'foreign_investment', 'government_investment', 'credit_to_agri', 'emission_indicators', 
    'employment_indicators', 'annual_population', 'agri_trade_indicators', 
    'nitrogen_fertilizer', 'phosphorus_fertilizer', 'potassium_fertilizer', 
    'cropland_nutrient_balance', 'pesticide', 'pesticide_trade', 'temperature_change'
] 

# list of table names (excluding 'producer_prices' and 'crop_production') 
# that are to be joined based on key_cols_1
table_group_1 = [
    'production_value', 'production_index',
    'trade', 'trade_indicators', 'trade_indices' 
]

# joining tables to form an integrated table/dataframe
df_merged = dfs['producer_prices'].merge(dfs['crop_production'], on=key_cols_1, how='left')
for table in table_names:
    if table in table_group_1:
        df_merged = df_merged.merge(dfs[table], on=key_cols_1, how='left')
    else:
        df_merged = df_merged.merge(dfs[table], on=key_cols_2, how='left')

df_merged.head()
# Out:
#    area_code     area  year_code  year  item_code   item  producer_price  \
# 0          1  Armenia       1997  1997         15  Wheat           225.3
# 1          1  Armenia       1998  1998         15  Wheat           205.6
# 2          1  Armenia       1999  1999         15  Wheat           177.5
# 3          1  Armenia       2000  2000         15  Wheat           163.5
# 4          1  Armenia       2001  2001         15  Wheat           166.0
#
#    producer_price_index  area_harvested  laying  milk_animals  \
# 0                 89.40        108000.0     NaN           NaN
# 1                 83.91        118300.0     NaN           NaN
# 2                 76.79        110129.0     NaN           NaN
# 3                 71.30        106581.0     NaN           NaN
# 4                 74.51        108554.0     NaN           NaN
#
#    producing_animals_or_slaughtered  production   yield  \
# 0                               NaN    183700.0  1700.9
# 1                               NaN    244300.0  2065.1
# 2                               NaN    214380.0  1946.6
# 3                               NaN    177762.0  1667.9
# 4                               NaN    241679.0  2226.3
#
#    yield_or_carcass_weight  gross_production_value  gross_production_index  \
# 0                      NaN                 50189.0                   52.42
# 1                      NaN                 66745.0                   69.72
# 2                      NaN                 58571.0                   61.18
# 3                      NaN                 48566.0                   50.73
# 4                      NaN                 66029.0                   68.97
#
#    area_agri_land  area_arable_land  area_cropland  area_with_irrigation  \
# 0          1332.0             455.0          498.0                 285.0
# 1          1328.0             455.0          493.0                 285.0
# 2          1323.0             450.0          488.0                 274.0
# 3          1323.0             450.0          488.0                 274.0
# 4          1328.0             455.0          493.0                 274.0
#
#    area_permanent_crops  area_temporary_crops  value_per_unit_agri_land  \
# 0                  43.0                   NaN                    637.93
# 1                  38.0                   NaN                    694.61
# 2                  38.0                   NaN                    691.05
# 3                  38.0                   NaN                    670.41
# 4                  38.0                 318.5                    693.99
#
#    cropland_area_per_capita  export_quantity  export_value  import_quantity  \
# 0                    0.1522              NaN           NaN         210742.0
# 1                    0.1521              NaN           NaN         282127.0
# 2                    0.1522              NaN           NaN         239694.0
# 3                    0.1540              NaN           NaN         375221.0
# 4                    0.1574              NaN           NaN         294960.0
#
#    import_value  export_market_concentration_index  import_dependency_ratio  \
# 0       50366.0                                NaN                      NaN
# 1       40100.0                                NaN                      NaN
# 2       37686.0                                NaN                      NaN
# 3       53695.0                                NaN                      NaN
# 4       42391.0                                NaN                      NaN
#
#    import_market_concentration_index  revealed_comparative_advantage_index  \
# 0                                NaN                                   NaN
# 1                                NaN                                   NaN
# 2                                NaN                                   NaN
# 3                                NaN                                   NaN
# 4                                NaN                                   NaN
#
#    self_sufficiency_ratio  terms_of_trade  export_quantity_index  \
# 0                     NaN             NaN                    NaN
# 1                     NaN             NaN                    NaN
# 2                     NaN             NaN                    NaN
# 3                     NaN             NaN                    NaN
# 4                     NaN             NaN                    NaN
#
#    export_value_index  import_quantity_index  import_value_index  \
# 0                 NaN                   69.0                65.0
# 1                 NaN                   93.0                52.0
# 2                 NaN                   79.0                49.0
# 3                 NaN                  123.0                70.0
# 4                 NaN                   97.0                55.0
#
#    gross_domestic_product  gross_fixed_capital_formation  \
# 0             3321.410346                     584.593684
# 1             3565.209041                     654.999152
# 2             3681.264873                     658.736569
# 3             3898.298463                     765.591218
# 4             4270.847611                     806.204236
#
#    value_added_ag_forest_fish  gdp_annual_growth  gfcf_annual_growth  \
# 0                  636.264290           3.321007            2.099717
# 1                  718.342383           7.340216           12.043487
# 2                  728.720081           3.255232            0.570598
# 3                  720.704274           5.895625           16.221150
# 4                  805.026484           9.556711            5.304791
#
#    value_added_ag_forest_fish_annual_growth  gfcf_share_in_total_gdp  \
# 0                                 -4.499913                17.600767
# 1                                 12.899999                18.371970
# 2                                  1.444672                17.894300
# 3                                 -1.099985                19.639112
# 4                                 11.699973                18.876914
#
#    ag_forest_fish_share_in_total_gdp  fdi_ag_forest_fish  fdi_food_industry  \
# 0                          19.156449                 NaN                NaN
# 1                          20.148675                 NaN                NaN
# 2                          19.795372                 NaN                NaN
# 3                          18.487663                 NaN         -19.505502
# 4                          18.849338              0.3781           5.293404
#
#    total_fdi_inflows  fdi_ag_forest_fish_share  fdi_food_industry_share  \
# 0          98.719641                       NaN                      NaN
# 1         410.567815                       NaN                      NaN
# 2         228.265384                       NaN                      NaN
# 3         199.262087                       NaN                -9.788868
# 4         132.146060                  0.286123                 4.005722
#
#    agri_orientation_index_govt_expenditure  govt_expenditure_on_ag  \
# 0                                      NaN                     NaN
# 1                                      NaN                     NaN
# 2                                      NaN                     NaN
# 3                                      NaN                     NaN
# 4                                      NaN                     NaN
#
#    govt_expenditure_on_ag_forest_fish  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#    ag_forest_fish_as_share_of_total_expenditure  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    credit_to_ag_forest_fish_2015_usd  ...  emission_share_land_use_change  \
# 0                                NaN  ...                            1.04
# 1                                NaN  ...                            1.02
# 2                                NaN  ...                            1.10
# 3                          36.830029  ...                            1.00
# 4                          32.007980  ...                            3.76
#
#    emission_share_pre_and_post_production  emission_share_end_to_end_agrifood  \
# 0                                   11.44                               37.20
# 1                                   11.60                               35.42
# 2                                   13.46                               39.23
# 3                                   15.17                               39.64
# 4                                   16.42                               43.63
#
#    emission_share_crops  emission_share_livestock  \
# 0                  1.40                     19.88
# 1                  1.63                     17.86
# 2                  1.31                     19.64
# 3                  1.18                     18.03
# 4                  1.13                     18.33
#
#    emission_share_ipcc_agriculture  emission_share_energy_use  \
# 0                            21.30                      60.86
# 1                            19.53                      62.03
# 2                            20.97                      59.99
# 3                            19.25                      63.38
# 4                            19.51                      63.13
#
#    emission_share_agri_waste_mgt  value_added_per_worker  employment_in_agri  \
# 0                          11.12                  873.68              728.26
# 1                          10.96                  976.11              735.92
# 2                          11.73                 1014.60              718.23
# 3                          10.97                 1006.95              715.73
# 4                          10.93                 1131.27              711.61
#
#    agri_employment_share_in_total_employment  total_employment_afs  \
# 0                                       56.1                   NaN
# 1                                       56.1                   NaN
# 2                                       56.0                   NaN
# 3                                       55.9                852.09
# 4                                       55.7                850.33
#
#    afs_employment_share_in_total_employment  rural_population  \
# 0                                       NaN          1080.782
# 1                                       NaN          1081.011
# 2                                       NaN          1082.796
# 3                                     66.56          1084.598
# 4                                     66.54          1086.476
#
#    urban_population  total_population  agri_trade_openness_index  \
# 0          2052.304          3246.289                        NaN
# 1          2027.673          3208.401                        NaN
# 2          2006.221          3167.286                        NaN
# 3          1984.990          3125.628                        NaN
# 4          1964.179          3084.349                        NaN
#
#    share_of_agri_exports_to_gdp  nitrogen_agri_use  nitrogen_export_quantity  \
# 0                           NaN             8000.0                      0.00
# 1                           NaN             9620.0                      0.00
# 2                           NaN             6158.0                      0.09
# 3                           NaN             7000.0                      0.14
# 4                           NaN             5000.0                      0.01
#
#    nitrogen_import_quantity  nitrogen_production  \
# 0                    8000.0                  NaN
# 1                    9620.0                  NaN
# 2                    6158.0                  NaN
# 3                    7000.0                  NaN
# 4                    5000.0                  NaN
#
#    nitrogen_use_per_area_of_cropland  nitrogen_use_per_capita  \
# 0                              16.06                     2.45
# 1                              19.51                     2.97
# 2                              12.62                     1.92
# 3                              14.34                     2.21
# 4                              10.14                     1.60
#
#    nitrogen_use_per_value_of_ag_production  phosphorus_agri_use  \
# 0                                     9.41                  NaN
# 1                                    10.43                  NaN
# 2                                     6.74                  NaN
# 3                                     7.89                  NaN
# 4                                     5.43                  NaN
#
#    phosphorus_export_quantity  phosphorus_import_quantity  \
# 0                      2300.0                        3.30
# 1                         0.0                        0.00
# 2                         0.0                        1.50
# 3                         0.0                        0.00
# 4                         0.0                       19.26
#
#    phosphorus_production  phosphorus_use_per_area_of_cropland  \
# 0                    NaN                                  NaN
# 1                    NaN                                  NaN
# 2                    NaN                                  NaN
# 3                    NaN                                  NaN
# 4                    NaN                                  NaN
#
#    phosphorus_use_per_capita  phosphorus_use_per_value_of_ag_production  \
# 0                        NaN                                        NaN
# 1                        NaN                                        NaN
# 2                        NaN                                        NaN
# 3                        NaN                                        NaN
# 4                        NaN                                        NaN
#
#    potassium_agri_use  potassium_export_quantity  potassium_import_quantity  \
# 0                 NaN                     365.03                       6.52
# 1                 NaN                       0.00                       0.00
# 2                 NaN                       0.00                       6.22
# 3                 NaN                       0.00                      10.71
# 4                 NaN                       0.00                      49.71
#
#    potassium_use_per_area_of_cropland  potassium_use_per_capita  \
# 0                                 NaN                       NaN
# 1                                 NaN                       NaN
# 2                                 NaN                       NaN
# 3                                 NaN                       NaN
# 4                                 NaN                       NaN
#
#    potassium_use_per_value_of_ag_production  cropland_nitrogen_per_unit_area  \
# 0                                       NaN                          24.0845
# 1                                       NaN                          23.4530
# 2                                       NaN                          18.1205
# 3                                       NaN                          22.7442
# 4                                       NaN                          13.3452
#
#    cropland_nitrogen_use_efficiency  cropland_phosphorus_per_unit_area  \
# 0                           39.6858                             0.6367
# 1                           45.4276                            -0.4984
# 2                           50.6764                            -0.4698
# 3                           40.0838                            -0.3237
# 4                           61.1667                            -1.7765
#
#    cropland_phosphorus_use_efficiency  cropland_potassium_per_unit_area  \
# 0                             83.1393                           -0.3189
# 1                            114.7784                           -2.8850
# 2                            114.6871                           -2.7453
# 3                            112.3245                           -1.9773
# 4                            176.5419                           -4.5395
#
#    cropland_potassium_use_efficiency  total_pesticide_use_for_agriculture  \
# 0                           103.1832                                41.46
# 1                           131.0245                                50.92
# 2                           130.0706                                60.38
# 3                           125.2821                                69.85
# 4                           159.8944                                79.31
#
#    total_pesticide_use_per_area_of_cropland  total_pesticide_use_per_capita  \
# 0                                      0.08                            0.01
# 1                                      0.10                            0.02
# 2                                      0.12                            0.02
# 3                                      0.14                            0.02
# 4                                      0.16                            0.03
#
#    total_pesticide_use_per_value_of_agri_production  \
# 0                                              0.05
# 1                                              0.06
# 2                                              0.07
# 3                                              0.08
# 4                                              0.09
#
#    total_pesticide_export_quantity  total_pesticide_export_value  \
# 0                            3.604                         3.687
# 1                            3.604                         3.687
# 2                            3.604                         3.687
# 3                            3.604                         3.687
# 4                            1.145                         9.068
#
#    total_pesticide_import_quantity  total_pesticide_import_value  \
# 0                          117.861                       298.379
# 1                          207.171                       340.124
# 2                          296.481                       381.869
# 3                          160.902                       482.955
# 4                          200.884                       698.022
#
#    temp_change_dec_jan_feb  temp_change_mar_apr_may  temp_change_jun_jul_aug  \
# 0                    2.166                   -0.319                    0.870
# 1                   -0.259                    1.483                    2.145
# 2                    3.535                    0.814                    1.611
# 3                    1.148                    0.723                    2.166
# 4                    1.818                    2.072                    1.578
#
#    temp_change_sep_oct_nov  temp_change_meteorological_year
# 0                    0.184                            0.725
# 1                    2.027                            1.349
# 2                    0.264                            1.556
# 3                    0.364                            1.100
# 4                    0.409                            1.469
#
# [5 rows x 117 columns]

# %%
df_merged.shape
# Out:
# (392856, 117)

# %%
# exporting integrated dataset as csv file
df_merged.to_csv('/Users/gurjitsingh/Desktop/MS Data Science/MS_Project_Python/integrated_data.csv', index=False)
