# %%
import pandas as pd
import numpy as np

# %%
# Loading data
raw_data = pd.read_csv('Datasets_MS_Project/Foreign_Direct_Investment/Investment_ForeignDirectInvestment_E_All_Data_(Normalized)/Investment_ForeignDirectInvestment_E_All_Data_(Normalized).csv')
raw_data.head()
# Out:
#    Area Code Area Code (M49)         Area  Item Code               Item  \
# 0          2            '004  Afghanistan      23082  Total FDI inflows
# 1          2            '004  Afghanistan      23082  Total FDI inflows
# 2          2            '004  Afghanistan      23082  Total FDI inflows
# 3          2            '004  Afghanistan      23082  Total FDI inflows
# 4          2            '004  Afghanistan      23082  Total FDI inflows
#
#    Element Code    Element  Year Code  Year         Unit    Value Flag    Note
# 0          6110  Value US$       1990  1990  million USD  0.00001    X  UNCTAD
# 1          6110  Value US$       1991  1991  million USD -0.28000    X  UNCTAD
# 2          6110  Value US$       1992  1992  million USD  0.36000    X  UNCTAD
# 3          6110  Value US$       1993  1993  million USD -0.02000    X  UNCTAD
# 4          6110  Value US$       1994  1994  million USD  0.02000    X  UNCTAD

# %%
raw_data.shape
# Out:
# (40442, 13)

# %%
raw_data['Item'].unique()
# Out:
# array(['Total FDI inflows', 'Total FDI outflows',
#        'FDI inflows to Agriculture, Forestry and Fishing',
#        'FDI inflows to Food, Beverages and Tobacco',
#        'FDI outflows to Agriculture, Forestry and Fishing',
#        'FDI outflows to Food, Beverages and Tobacco'], dtype=object)

# %%
raw_data['Element'].unique()
# Out:
# array(['Value US$', 'Value US$, 2015 prices',
#        'Share of Total FDI inflows US$, 2015 prices',
#        'Share of Total FDI outflows US$, 2015 prices'], dtype=object)

# %% [markdown]
# For our project, we would consider just the FDI inflows because investments
# coming into the country from foreign entities are generally more significant to
# farmer producer prices.
#
# Moreover, two kinds of meterics will be used to measure FDI inflows:
# 'Value US$, 2015 prices', and 'Share of Total FDI inflows US$, 2015 prices'

# %%
# Filter the dataset for desired items and elements
items_to_keep = [
    'Total FDI inflows', 
    'FDI inflows to Agriculture, Forestry and Fishing', 
    'FDI inflows to Food, Beverages and Tobacco'
]

elements_to_keep = [
    'Value US$, 2015 prices',
    'Share of Total FDI inflows US$, 2015 prices'
]

filtered_data = raw_data.loc[
    (raw_data['Item'].isin(items_to_keep)) &
    (raw_data['Element'].isin(elements_to_keep))
]
filtered_data.head()
# Out:
#     Area Code Area Code (M49)         Area  Item Code               Item  \
# 32          2            '004  Afghanistan      23082  Total FDI inflows
# 33          2            '004  Afghanistan      23082  Total FDI inflows
# 34          2            '004  Afghanistan      23082  Total FDI inflows
# 35          2            '004  Afghanistan      23082  Total FDI inflows
# 36          2            '004  Afghanistan      23082  Total FDI inflows
#
#     Element Code                 Element  Year Code  Year         Unit  \
# 32          6184  Value US$, 2015 prices       1990  1990  million USD
# 33          6184  Value US$, 2015 prices       1991  1991  million USD
# 34          6184  Value US$, 2015 prices       1992  1992  million USD
# 35          6184  Value US$, 2015 prices       1993  1993  million USD
# 36          6184  Value US$, 2015 prices       1994  1994  million USD
#
#        Value Flag    Note
# 32  0.000024    X  UNCTAD
# 33 -0.652408    X  UNCTAD
# 34  0.819359    X  UNCTAD
# 35 -0.044542    X  UNCTAD
# 36  0.043630    X  UNCTAD

# %%
filtered_data['Item'].unique()
# Out:
# array(['Total FDI inflows',
#        'FDI inflows to Agriculture, Forestry and Fishing',
#        'FDI inflows to Food, Beverages and Tobacco'], dtype=object)

# %%
filtered_data['Element'].unique()
# Out:
# array(['Value US$, 2015 prices',
#        'Share of Total FDI inflows US$, 2015 prices'], dtype=object)

# %%
filtered_data['Item'].value_counts()
# Out:
# Item
# Total FDI inflows                                   7666
# FDI inflows to Agriculture, Forestry and Fishing    3302
# FDI inflows to Food, Beverages and Tobacco          2310
# Name: count, dtype: int64

# %% [markdown]
# We can make two separate datasets based on the two elements- value in USD and
# share towards total FDI (%). Later, we can combine these two datasets to make
# an integrated dataset.

# %% [markdown]
# ## FDI in terms of USD, 2015 prices

# %%
filtered_data_1 = filtered_data.loc[filtered_data['Element']=='Value US$, 2015 prices']
filtered_data_1.head()
# Out:
#     Area Code Area Code (M49)         Area  Item Code               Item  \
# 32          2            '004  Afghanistan      23082  Total FDI inflows
# 33          2            '004  Afghanistan      23082  Total FDI inflows
# 34          2            '004  Afghanistan      23082  Total FDI inflows
# 35          2            '004  Afghanistan      23082  Total FDI inflows
# 36          2            '004  Afghanistan      23082  Total FDI inflows
#
#     Element Code                 Element  Year Code  Year         Unit  \
# 32          6184  Value US$, 2015 prices       1990  1990  million USD
# 33          6184  Value US$, 2015 prices       1991  1991  million USD
# 34          6184  Value US$, 2015 prices       1992  1992  million USD
# 35          6184  Value US$, 2015 prices       1993  1993  million USD
# 36          6184  Value US$, 2015 prices       1994  1994  million USD
#
#        Value Flag    Note
# 32  0.000024    X  UNCTAD
# 33 -0.652408    X  UNCTAD
# 34  0.819359    X  UNCTAD
# 35 -0.044542    X  UNCTAD
# 36  0.043630    X  UNCTAD

# %%
filtered_data_1['Element'].unique()
# Out:
# array(['Value US$, 2015 prices'], dtype=object)

# %%
filtered_data_1['Item'].value_counts()
# Out:
# Item
# Total FDI inflows                                   7666
# FDI inflows to Agriculture, Forestry and Fishing    1651
# FDI inflows to Food, Beverages and Tobacco          1155
# Name: count, dtype: int64

# %%
# restructuring data from long to wide format
pivoted_data_1 = filtered_data_1.pivot_table(
    index = ['Area Code', 'Area', 'Year Code', 'Year'],
    columns = 'Item',
    values = 'Value'
)

# resetting row index
pivoted_data_1.reset_index(inplace=True)

# setting column index name to None
pivoted_data_1.columns.name = None

pivoted_data_1.head()
# Out:
#    Area Code     Area  Year Code  Year  \
# 0          1  Armenia       1990  1990
# 1          1  Armenia       1991  1991
# 2          1  Armenia       1992  1992
# 3          1  Armenia       1993  1993
# 4          1  Armenia       1994  1994
#
#    FDI inflows to Agriculture, Forestry and Fishing  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    FDI inflows to Food, Beverages and Tobacco  Total FDI inflows
# 0                                         NaN           9.738913
# 1                                         NaN          47.391556
# 2                                         NaN           5.667964
# 3                                         NaN           1.845575
# 4                                         NaN          18.069882

# %%
# renaming columns
cleaned_data_1 = pivoted_data_1.rename(
    columns = {
        'Area Code': 'area_code',
        'Area': 'area',
        'Year Code': 'year_code',
        'Year': 'year',
        'FDI inflows to Agriculture, Forestry and Fishing': 'FDI_ag_forest_fish',
        'FDI inflows to Food, Beverages and Tobacco': 'FDI_food_industry',
        'Total FDI inflows': 'total_FDI_inflows'
    }
)
cleaned_data_1.head()
# Out:
#    area_code     area  year_code  year  FDI_ag_forest_fish  FDI_food_industry  \
# 0          1  Armenia       1990  1990                 NaN                NaN
# 1          1  Armenia       1991  1991                 NaN                NaN
# 2          1  Armenia       1992  1992                 NaN                NaN
# 3          1  Armenia       1993  1993                 NaN                NaN
# 4          1  Armenia       1994  1994                 NaN                NaN
#
#    total_FDI_inflows
# 0           9.738913
# 1          47.391556
# 2           5.667964
# 3           1.845575
# 4          18.069882

# %% [markdown]
# ## FDI in terms of 'Share of Total FDI inflows US$, 2015 prices'

# %%
filtered_data_2 = filtered_data.loc[filtered_data['Element']=='Share of Total FDI inflows US$, 2015 prices']
filtered_data_2.head()
# Out:
#      Area Code Area Code (M49)     Area  Item Code  \
# 134          3            '008  Albania      23080
# 135          3            '008  Albania      23080
# 136          3            '008  Albania      23080
# 137          3            '008  Albania      23080
# 138          3            '008  Albania      23080
#
#                                                  Item  Element Code  \
# 134  FDI inflows to Agriculture, Forestry and Fishing         61410
# 135  FDI inflows to Agriculture, Forestry and Fishing         61410
# 136  FDI inflows to Agriculture, Forestry and Fishing         61410
# 137  FDI inflows to Agriculture, Forestry and Fishing         61410
# 138  FDI inflows to Agriculture, Forestry and Fishing         61410
#
#                                          Element  Year Code  Year Unit  \
# 134  Share of Total FDI inflows US$, 2015 prices       2004  2004    %
# 135  Share of Total FDI inflows US$, 2015 prices       2005  2005    %
# 136  Share of Total FDI inflows US$, 2015 prices       2006  2006    %
# 137  Share of Total FDI inflows US$, 2015 prices       2007  2007    %
# 138  Share of Total FDI inflows US$, 2015 prices       2008  2008    %
#
#         Value Flag Note
# 134  0.190478    X  NaN
# 135  0.188456    X  NaN
# 136  0.772201    X  NaN
# 137  0.416667    X  NaN
# 138 -8.120301    X  NaN

# %%
filtered_data_2['Item'].value_counts()
# Out:
# Item
# FDI inflows to Agriculture, Forestry and Fishing    1651
# FDI inflows to Food, Beverages and Tobacco          1155
# Name: count, dtype: int64

# %%
# restructuring data from long to wide format
pivoted_data_2 = filtered_data_2.pivot_table(
    index = ['Area Code', 'Area', 'Year Code', 'Year'],
    columns = 'Item',
    values = 'Value'
)

# resetting row index
pivoted_data_2.reset_index(inplace=True)

# setting column index name to None
pivoted_data_2.columns.name = None

pivoted_data_2.head()
# Out:
#    Area Code     Area  Year Code  Year  \
# 0          1  Armenia       2000  2000
# 1          1  Armenia       2001  2001
# 2          1  Armenia       2002  2002
# 3          1  Armenia       2003  2003
# 4          1  Armenia       2004  2004
#
#    FDI inflows to Agriculture, Forestry and Fishing  \
# 0                                               NaN
# 1                                          0.286123
# 2                                          3.068592
# 3                                               NaN
# 4                                               NaN
#
#    FDI inflows to Food, Beverages and Tobacco
# 0                                   -9.788868
# 1                                    4.005722
# 2                                    5.956679
# 3                                    6.365964
# 4                                   14.767661

# %%
# renaming columns
cleaned_data_2 = pivoted_data_2.rename(
    columns = {
        'Area Code': 'area_code',
        'Area': 'area',
        'Year Code': 'year_code',
        'Year': 'year',
        'FDI inflows to Agriculture, Forestry and Fishing': 'FDI_ag_forest_fish_share',
        'FDI inflows to Food, Beverages and Tobacco': 'FDI_food_industry_share'
    }
)
cleaned_data_2.head()
# Out:
#    area_code     area  year_code  year  FDI_ag_forest_fish_share  \
# 0          1  Armenia       2000  2000                       NaN
# 1          1  Armenia       2001  2001                  0.286123
# 2          1  Armenia       2002  2002                  3.068592
# 3          1  Armenia       2003  2003                       NaN
# 4          1  Armenia       2004  2004                       NaN
#
#    FDI_food_industry_share
# 0                -9.788868
# 1                 4.005722
# 2                 5.956679
# 3                 6.365964
# 4                14.767661

# %%
cleaned_data_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1887 entries, 0 to 1886
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   area_code                 1887 non-null   int64
#  1   area                      1887 non-null   object
#  2   year_code                 1887 non-null   int64
#  3   year                      1887 non-null   int64
#  4   FDI_ag_forest_fish_share  1651 non-null   float64
#  5   FDI_food_industry_share   1155 non-null   float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 88.6+ KB

# %%
cleaned_data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7666 entries, 0 to 7665
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   area_code           7666 non-null   int64
#  1   area                7666 non-null   object
#  2   year_code           7666 non-null   int64
#  3   year                7666 non-null   int64
#  4   FDI_ag_forest_fish  1651 non-null   float64
#  5   FDI_food_industry   1155 non-null   float64
#  6   total_FDI_inflows   7666 non-null   float64
# dtypes: float64(3), int64(3), object(1)
# memory usage: 419.4+ KB

# %% [markdown]
# ## Combining two datasets

# %%
merged_data = pd.merge(
    cleaned_data_1, cleaned_data_2, 
    on=['area_code', 'area', 'year_code', 'year'],
    how = 'left'
)

merged_data.head()
# Out:
#    area_code     area  year_code  year  FDI_ag_forest_fish  FDI_food_industry  \
# 0          1  Armenia       1990  1990                 NaN                NaN
# 1          1  Armenia       1991  1991                 NaN                NaN
# 2          1  Armenia       1992  1992                 NaN                NaN
# 3          1  Armenia       1993  1993                 NaN                NaN
# 4          1  Armenia       1994  1994                 NaN                NaN
#
#    total_FDI_inflows  FDI_ag_forest_fish_share  FDI_food_industry_share
# 0           9.738913                       NaN                      NaN
# 1          47.391556                       NaN                      NaN
# 2           5.667964                       NaN                      NaN
# 3           1.845575                       NaN                      NaN
# 4          18.069882                       NaN                      NaN

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7666 entries, 0 to 7665
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   area_code                 7666 non-null   int64
#  1   area                      7666 non-null   object
#  2   year_code                 7666 non-null   int64
#  3   year                      7666 non-null   int64
#  4   FDI_ag_forest_fish        1651 non-null   float64
#  5   FDI_food_industry         1155 non-null   float64
#  6   total_FDI_inflows         7666 non-null   float64
#  7   FDI_ag_forest_fish_share  1651 non-null   float64
#  8   FDI_food_industry_share   1155 non-null   float64
# dtypes: float64(5), int64(3), object(1)
# memory usage: 539.1+ KB

# %%
# exporting cleaned data as csv file
merged_data.to_csv('cleaned_datasets/foreign_investment_cleaned.csv', index='False')
